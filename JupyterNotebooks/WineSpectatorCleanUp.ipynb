# %%
import pandas as pd

# %%
import json
import urllib
import requests

# %%
headers = {
    'X-Parse-Application-Id': 'ahcIqV3eVlD2kiltn2kLf9ewWo8URJ1QC2V4udJC', # This is the fake app's application id
    'X-Parse-Master-Key': '2TRj0qgPlJotQJn3uPwNTUxTAbKdWB6szvQ1vcWc' # This is the fake app's readonly master key
}

allWines = []
skip=0;

for x in range (0,32):
    url = f'https://parseapi.back4app.com/classes/top100?skip={skip}&order=ListYear'
    data = json.loads(requests.get(url, headers=headers).content.decode('utf-8')) 
    
    for i in range (0,100):
        reference=data['results'][i]
        try:
            rank=reference['Rank']
            wine=reference['Wine']
            winery=reference['Winery']
            vintage=reference['Vintage']
            score=reference['Score']
            price=reference['Price']
            notes=reference['Notes']
            listYear=reference['ListYear']
            
            allWines.append({"Rank":rank, "Wine":wine,"Winery":winery,
                             "Vintage":vintage,"Score":score,"Price":price,
                             "Notes":notes,"ListYear":listYear})
        except:
            print('missing information')
    skip=skip+100
# Out:
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information
# missing information

# %%
wineDF=pd.DataFrame.from_dict(allWines)
wineDF.head(50)
# Out:
#     Rank                                               Wine  \
# 0     24                Antinori Chianti Classico Pèppoli +
# 1     29  Bonny Doon Pinot Noir Oregon Bethel Heights Vi...
# 2     19        René & Vincent Dauvissat Chablis Les Clos +
# 3      1                     Château Lynch Bages Pauillac +
# 4     31  B.R. Cohn Cabernet Sauvignon Sonoma Valley Oli...
# 5     35                          Château Latour Pauillac +
# 6     69                       Château Rieussec Sauternes +
# 7     37             Domaine de la Romanée-Conti La Tâche +
# 8     49  Daniel Rion & Fils Vosne-Romanée Les Beaux-Mon...
# 9     26  Penfolds Grange Hermitage South Australia Bin ...
# 10    41  Kendall-Jackson Cabernet Sauvignon California ...
# 11    27  Bodegas Alejandro Fernandez Ribera del Duero P...
# 12    78          A. Rafanelli Zinfandel Dry Creek Valley +
# 13    60                   Pierre Gelin Gevrey-Chambertin +
# 14    25                    Torres Penedès White Milmanda +
# 15    42   Louis Jadot Nuits-St.-Georges Clos des Corvées +
# 16     6   Castellare di Castellina I Sodi di San Niccolò +
# 17    57          Kendall-Jackson Merlot Alexander Valley +
# 18    12                                   Pétrus Pomerol +
# 19    50                           Château Climens Barsac +
# 20    58                        Château du Tertre Margaux +
# 21    73        Château Rayas Châteauneuf-du-Pape Réservé +
# 22    11  Louis Latour Romanée St.-Vivant Les Quatre Jou...
# 23    10    Joseph Drouhin Montrachet Marquis de Laguiche +
# 24     3           Domaine de la Romanée-Conti Richebourg +
# 25     5                      Gaja Barbaresco Sorì Tildìn +
# 26    51                       Château Figeac St.-Emilion +
# 27    40                   Ca' del Bosco Maurizio Zanella +
# 28    15  Ridge Cabernet Sauvignon Santa Cruz Mountains ...
# 29    30                            Domenico Clerico Arte +
# 30    44       Frog's Leap Cabernet Sauvignon Napa Valley +
# 31    14                 Gaja Barbaresco Sorì San Lorenzo +
# 32    13                      Gaja Barbaresco Costa Russi +
# 33    83  Inglenook-Napa Valley Merlot Napa Valley Reser...
# 34    63                Avignonesi Chardonnay Il Marzocco +
# 35    28                 San Felice Predicato di Bitùrica +
# 36    89             Husch Gewürztraminer Anderson Valley +
# 37    61       Paul Jaboulet Aîné Côte-Rôtie Les Jumelles +
# 38    68            Bollinger Brut Champagne Grande Année +
# 39    45    Robert Mondavi Cabernet Sauvignon Napa Valley +
# 40    56                    Girard Chardonnay Napa Valley +
# 41    21  Marchesi de' Frescobaldi Pomino Tenuta di Pomi...
# 42    16                   Château Beychevelle St.-Julien +
# 43    18             Château Ducru-Beaucaillou St.-Julien +
# 44    32        Arrowood Cabernet Sauvignon Sonoma County +
# 45    47  Chateau Montelena Cabernet Sauvignon Napa Vall...
# 46    17      Château Pichon Longueville Lalande Pauillac +
# 47    54      Biondi-Santi Brunello di Montalcino Riserva +
# 48    43                         Jaffelin Clos de Vougeot +
# 49     2                          Château Margaux Margaux +
#
#                                 Winery  Vintage  Score  Price  \
# 0                             Antinori     1985     92   16.0
# 1                           Bonny Doon     1985     90   18.0
# 2             René & Vincent Dauvissat     1986     95   40.0
# 3                  Château Lynch Bages     1985     97   37.0
# 4                            B.R. Cohn     1985     94   16.0
# 5                       Château Latour     1985     97   90.0
# 6                     Château Rieussec     1983     94   52.0
# 7          Domaine de la Romanée-Conti     1985     98  225.0
# 8                   Daniel Rion & Fils     1985     95   55.0
# 9                             Penfolds     1981     93   49.0
# 10                     Kendall-Jackson     1985     95   20.0
# 11         Bodegas Alejandro Fernandez     1982     94   75.0
# 12                        A. Rafanelli     1986     91    7.0
# 13                        Pierre Gelin     1985     93   25.0
# 14                              Torres     1987     94   35.0
# 15                         Louis Jadot     1985     96   46.0
# 16            Castellare di Castellina     1985     96   25.0
# 17                     Kendall-Jackson     1986     93   16.0
# 18                              Pétrus     1985     98  160.0
# 19                     Château Climens     1983     95   50.0
# 20                   Château du Tertre     1985     93   14.0
# 21                       Château Rayas     1985     93   41.0
# 22                        Louis Latour     1985     98   99.0
# 23                      Joseph Drouhin     1986     97  200.0
# 24         Domaine de la Romanée-Conti     1985    100  210.0
# 25                                Gaja     1985     97   94.0
# 26                      Château Figeac     1985     95   37.0
# 27                       Ca' del Bosco     1985     92   38.0
# 28                               Ridge     1985     95   35.0
# 29                    Domenico Clerico     1985     91   22.0
# 30                         Frog's Leap     1986     94   14.0
# 31                                Gaja     1985     96   88.0
# 32                                Gaja     1985     96   83.0
# 33               Inglenook-Napa Valley     1985     91   14.0
# 34                          Avignonesi     1986     92   16.0
# 35                          San Felice     1982     92   19.0
# 36                               Husch     1987     90    7.0
# 37                  Paul Jaboulet Aîné     1985     93   35.0
# 38                           Bollinger     1982     93   30.0
# 39                      Robert Mondavi     1985     94   15.0
# 40                              Girard     1986     93   14.0
# 41            Marchesi de' Frescobaldi     1985     93   12.0
# 42                 Château Beychevelle     1985     95   35.0
# 43           Château Ducru-Beaucaillou     1985     95   50.0
# 44                            Arrowood     1985     94   19.0
# 45                   Chateau Montelena     1984     94   20.0
# 46  Château Pichon Longueville Lalande     1985     95   40.0
# 47                        Biondi-Santi     1982     94   80.0
# 48                            Jaffelin     1985     96   49.0
# 49                     Château Margaux     1985     99   76.0
#
#                                                 Notes  ListYear
# 0   Concentrated and beautifully formed, with shar...      1988
# 1   Very pretty aromas and flavors, featuring viol...      1988
# 2   Toasty and concentrated with rich pear, apple,...      1988
# 3   Rich and massively concentrated, with layers o...      1988
# 4   Gorgeous fruit, rich, supple, satiny with beau...      1988
# 5   A majestic wine, a bit hard and lean, with str...      1988
# 6   Nectar-like if a bit on the sweet side, impres...      1988
# 7   Impressive concentration and depth, the kind o...      1988
# 8   Tightly focused and concentrated, sending a cu...      1988
# 9   A masterpiece, loaded with rich, smoky, plum, ...      1988
# 10  Sleek and elegant with an overlay of toasty Fr...      1988
# 11  Deep, rich, ripe and powerful, with slightly e...      1988
# 12  Very firm and concentrated and focused, amazin...      1988
# 13  Firm and tannic, with concentrated raspberry, ...      1988
# 14  Stunning wine, beautifully balanced, smoothly ...      1988
# 15  Big, rich and deep, with incredible balance an...      1988
# 16  Loaded with rich, ripe, spicy, plummy fruit, h...      1988
# 17  Effusively fruity, bursting with cherry aroma ...      1988
# 18  A massive concentration of rich, intense plum,...      1988
# 19  Beautifully crafted, plump, very long and comp...      1988
# 20  Rich, complex and elegant, concentrated and in...      1988
# 21  Deliciously rich, ripe and jammy with effusive...      1988
# 22  Seamlessly complex, full of flavor yet so beau...      1988
# 23  Uncommon depth and complexity, the rich intens...      1988
# 24  A truly great wine. Amazing concentration, bri...      1988
# 25  A majestic wine, beautifully harmonious, seaml...      1988
# 26  Great intensity of flavor without too much wei...      1988
# 27  Smooth and supple, with rich berry, cherry and...      1988
# 28  Rich, tannic, intense and young, but it's pack...      1988
# 29  The distinctive raspberry tang of Nebbiolo is ...      1988
# 30  A beautiful wine, concentrated, velvety and el...      1988
# 31  A bit more austere than the others, but it han...      1988
# 32  Remarkable in its concentration and elegance, ...      1988
# 33  Deep in color and fairly tannic with deep berr...      1988
# 34  One of the greatest Italian whites ever. Rich ...      1988
# 35  Dark, dense and ripe, with concentrated cherry...      1988
# 36  Nearly identical to a fine Alsace Gewürz. Love...      1988
# 37  Full throttle Côte-Rôtie with gorgeous fruit, ...      1988
# 38  Rich, toasty and very assertive, high in extra...      1988
# 39  Distinct currant, cassis, cherry and vanilla f...      1988
# 40  Spicier, toastier and more complex than most C...      1988
# 41  Densely concentrated, both color and aroma, bu...      1988
# 42  Outstanding wine. Incredibly toasty and vanill...      1988
# 43  Lean and silky with amazingly intense, ripe pl...      1988
# 44  A luscious Cabernet, supple and silky, elegant...      1988
# 45  Deep, dark, concentrated and ripe, showing mas...      1988
# 46  A massive wine, rich with currant, leather and...      1988
# 47  Sharply focused, tightly wound, powerful, eleg...      1988
# 48  Intense of flavor but delicate of structure, o...      1988
# 49  A beautifully structured and proportioned wine...      1988
